# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

# %%
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)

# %%
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %%
frames = [df1, df2, df3]

# %% [markdown]
# ***CONCAT***

# %%
result = pd.concat(frames)

# %%
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ***HEAD - 5 items***

# %%
df1.head()
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2.head()
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3.head()
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ***TAIL***

# %%
df1.tail()
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2.tail()
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3.tail()
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ***SAMPLE***

# %%
df1.sample(2)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 3  A3  B3  C3  D3

# %%
df2.sample(2)
# Out:
#     A   B   C   D
# 5  A5  B5  C5  D5
# 4  A4  B4  C4  D4

# %%
df3.sample(2)
# Out:
#       A    B    C    D
# 10  A10  B10  C10  D10
# 8    A8   B8   C8   D8

# %% [markdown]
# ***Selecting/Filtering Data***

# %%
#SELECTING
df1['A']
# Out:
# 0    A0
# 1    A1
# 2    A2
# 3    A3
# Name: A, dtype: object

# %%
#Filtering
df1[['A', 'B']]
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %% [markdown]
# ***Adding/Removing Columns***

# %%
df1['E'] = ["E0", "E1", "E2", "E3"]

# %% [markdown]
# ***Handling Missing Data***

# %%
df1.isna()    # Check for missing values
df1.dropna()  # Drop rows with missing values
df1.fillna(0) # Fill missing values with 0
# Out:
#     A   B   C   D   E
# 0  A0  B0  C0  D0  E0
# 1  A1  B1  C1  D1  E1
# 2  A2  B2  C2  D2  E2
# 3  A3  B3  C3  D3  E3

# %% [markdown]
# ***Sorting***

# %%
df1.sort_values(by='A')         # Sort by Age
df1.sort_values(by=['A', 'B'])  # Sort by Name then Age
# Out:
#     A   B   C   D   E
# 0  A0  B0  C0  D0  E0
# 1  A1  B1  C1  D1  E1
# 2  A2  B2  C2  D2  E2
# 3  A3  B3  C3  D3  E3

# %% [markdown]
# ***Merging and Joining***

# %%
pd.merge(df1, df2, on='A')     # Merge based on a common key
# Out:
# Empty DataFrame
# Columns: [A, B_x, C_x, D_x, E, B_y, C_y, D_y]
# Index: []
